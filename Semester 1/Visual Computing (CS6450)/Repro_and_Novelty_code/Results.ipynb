# %% [markdown]
# ## Performance
#
# No | Task | Dataset | Metric | RMT (From Paper-Test) |  RMT (Reproduced-Eval) |  RMT (Reproduced-Test) | Notes
# -- | -- | -- | -- | -- | -- | --  |--
# 1 | LM* | WT-103 | ppl &darr; | **23.99** | 23.431 | __24.291__ (&uarr; 0.301) | 4 GPUs (V100), ~4 days, 188400/200000 steps (~94%) `bash run_wt103_base.sh train --num_mem_tokens 160`, `bash run_wt103_base.sh eval --work_dir LM-TFM-wt103/20230313-151556`
# 2 | LM* | enwik8 | bpc &darr;| **1.228** | ? | ? | `bash run_enwik8_base.sh train --num_mem_tokens 10`
# 3 | step-by-step | qudaratic equations | acc &uarr; | __99.8__| - | **99.9** (&uarr; 0.1)| `bash copy.sh train --num_mem_tokens 30 --tgt_len 128 --eval_tgt_len 128 `
# 4 | ~~Classification~~ | ~~(Hyperpartisan)~~ | ~~acc &uarr;~~ | ~~**98.1**~~ | ~~?~~ | ~~?~~ | No reproducibility instructions provided.
# ```bash

# %% [markdown]
# ## Performance
#
# No | Task | Dataset | Metric | RMT (From Paper-Test) |  RMT (Reproduced-Eval) |  RMT (Reproduced-Test) | Notes
# -- | -- | -- | -- | -- | -- | --  |--
# 1 | LM* | WT-103 | ppl &darr; | **23.99** | 23.431 | __24.291__ (&uarr; 0.301) | 4 GPUs (V100), ~4 days, 188400/200000 steps (~94%) `bash run_wt103_base.sh train --num_mem_tokens 160`, `bash run_wt103_base.sh eval --work_dir LM-TFM-wt103/20230313-151556`
# 2 | LM* | enwik8 | bpc &darr;| **1.228** | ? | ? | `bash run_enwik8_base.sh train --num_mem_tokens 10`
# 3 | step-by-step | qudaratic equations | acc &uarr; | __99.8__| - | **99.9** (&uarr; 0.1)| `bash copy.sh train --num_mem_tokens 30 --tgt_len 128 --eval_tgt_len 128 `
# 4 | ~~Classification~~ | ~~(Hyperpartisan)~~ | ~~acc &uarr;~~ | ~~**98.1**~~ | ~~?~~ | ~~?~~ | No reproducibility instructions provided.
# ```bash

# %% [markdown]
# ## 1
# ![image.png](attachment:image.png)
#
# ## 2
# ![image.png](attachment:image-3.png)
#
# ## 3
# ![image.png](attachment:image-4.png)
#
# ## 4
# ![image.png](attachment:image-2.png)
